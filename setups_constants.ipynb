# %%
import numpy as np
pi=np.pi

# Boltzmannkonstante (J/K)
kB = 1.3806488*10**(-23)

# universelle Gaskonstante (J/(K mol))
R = 8.31446261815324

# Avogadrokonstante (1/mol)
Na = 6.02214129*10**(23)

# Lichtgeschwindigkeit (m/s)
c = 299792458

# Plancksches Wirkumsquantum (Js)
h = 6.62606957*10**(-34)

# Reduziertes Plancksches Wirkumsquantum (Js)
hquer = h/2/pi

# Bohrsches Magneton  (A m^2 )
muB = 9.27400*10 ** (-24)

# Masse Elektron (kg)
me = 9.1093829*10**(-31)

# Masse Proton (kg)
M = 1.672621777*10**(-27)

# Masse Neutron  (kg)
Mn = 1.674927351*10**(-27)

# Elementarladung  (C)
e = 1.602176487*10**(-19)

# Gravitationskonstante  (m ^ 3/kg*s-^2)
G = 6.67384*10**(-11)

# Dielektrizitätskonstante (As/(Vm))
epsilon = 8.854187817*10**(-12)

# Magnetische Feldkonstannte (N/A ^ 2 )
mu = 12.566370614*10**(-7)

#  Mittlerer Erdradius  (m)
RErde = 6371000.785

# Masse der Erde  (kg)
MErde = 5.9722*10**(24)

# Sonnenradius (m)
RSonne = 6.957*10**(8)

# Sonnenmasse   (kg)
MSonne = 1.989*10**(30)

# Umrechnung atomare Masseneinheit ---> kg   (kg/u)
ame = 1.6605*10**(-27)

# Bohrradius (m)
ao = 4*pi*epsilon*hquer**2/(me*e**2)

# Umrechnung Elektronenvolt Joule  (J/eV)
eV = 1.6021766208*10**(-19)
